# %%
import Modulo_meteorologia as MM
import importlib
importlib.reload(MM)


programa = True 
tabMeteo = []

print("""
(1) Calcular a média da temperatura dos registos;
(2) Ver a menor temperatura mínima dos registos;
(3) Ver a maior temperatura máxima dos registos;
(4) Calcular a amplitude das temperaturas de cada dia registado;
(5) Ver o dia com a maior precipitação registada;
(6) Ver os dias com precipitação maior do que o valor p
(7) Ver o maior número de dias consecutivos com precipitação maior do que o valor p
(8) Ver os dias com precipitação menor do que o valor p
(9) Ver o maior número de dias consecutivos com precipitação menor do que o valor p
(10) Desenhar gráfico que representa os valores de temperatura máxima e mínima e os valores de precipitação
(11) Guardar ficheiro
(12) Carregar ficheiro
(0) Sair""")

while programa:
    sel = input("Escolha a função que pretende executar:")
    if sel == "1":
        print(MM.medias(tabMeteo))
    elif sel =="2":
        print(MM.minMin(tabMeteo))
    elif sel =="3":
        print(MM.maxMax(tabMeteo))
    elif sel =="4":
        print(MM.amplTerm(tabMeteo))
    elif sel =="5":
        print(MM.maxChuva(tabMeteo))
    elif sel =="6":
        valorp = float(input("Insira o valor limite p:"))
        print(MM.diasChuvosos(tabMeteo,valorp))
    elif sel == "7":
        valorp = float(input("Insira o valor limite p:"))
        print(MM.maxPeriodoChuva(tabMeteo,valorp))
    elif sel =="8":
        valorp = float(input("Insira o valor limite p:"))
        print(MM.diasSecos(tabMeteo,valorp))
    elif sel =="9":
        valorp = float(input("Insira o valor limite p:"))
        print(MM.maxPeriodoCalor(tabMeteo,valorp))
    elif sel =="10":
        print(MM.grafTabMeteo(tabMeteo))
    elif sel == "11" :
        fnome = input("Insira o nome no qual pretende guardar o ficheiro.")
        MM.guardaTabMeteo(tabMeteo,fnome)
    elif sel == "12" :
        fnome = input("Insira o nome do ficheiro que pretende carregar.")
        tabMeteo = MM.carregaTabMeteo(fnome)
    elif sel =="0":
        programa = MM.sairTabMeteoIn()
    else:
        print("Escolha inválida.")
# Out:
# (1) Calcular a média da temperatura dos registos;
# (2) Ver a menor temperatura mínima dos registos;
# (3) Ver a maior temperatura máxima dos registos;
# (4) Calcular a amplitude das temperaturas de cada dia registado;
# (5) Ver o dia com a maior precipitação registada;
# (6) Ver os dias com precipitação maior do que o valor p
# (7) Ver o maior número de dias consecutivos com precipitação maior do que o valor p
# (8) Ver os dias com precipitação menor do que o valor p
# (9) Ver o maior número de dias consecutivos com precipitação menor do que o valor p
# (10) Desenhar gráfico que representa os valores de temperatura máxima e mínima e os valores de precipitação
# (11) Guardar ficheiro
# (12) Carregar ficheiro
# (0) Sair
# Escolha inválida.
# []
# Escolha inválida.
# []
# None
